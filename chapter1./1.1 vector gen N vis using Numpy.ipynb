# %%
import numpy as np
asList = [1,2,3]
asArray = np.array([1,2,3])
rowVec = np.array([[1,2,3]])
colVec = np.array([[1],[2],[3]])

# %%
print(f'asList: {np.shape(asList)}')
print(f'asArray : {asArray.shape}') # 1-dim array 
print(f'rowVec : {rowVec.shape}') # row 
print(f'colVec : {colVec.shape}') #collum
# Out:
# asList: (3,)
# asArray : (3,)
# rowVec : (1, 3)
# colVec : (3, 1)
